# %% [markdown]
# # Week 3 Practice Tutorial: Feedforward Networks on MNIST
#
# **MATH3881 / MATH5881, UNSW.** Instructor: Sarat Moka.
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/saratmoka/MATH3881-5881/blob/main/tutorials/week03/Week3_Practice_Tutorial_Solutions.ipynb)
#
# Today you will do two things.
#
# **Problem 1.** Train your first feedforward neural network on MNIST, step by step, in PyTorch. You will see loss curves, overfitting, and what each piece of the training loop is doing.
#
# **Problem 2.** Test the *dropout-as-ensemble* claim empirically. Train one network with dropout, then separately train a handful of small thinned subnetworks and average their predictions. You should find that the two strategies give comparable test accuracy, which is the heart of why dropout works.
#
# The notebook is designed for Google Colab (no local install required). A CPU runtime is enough; GPU just makes it faster. Estimated total running time on CPU: about 5 minutes.

# %% [markdown]
# ## Setup

# %% [markdown]
# We import PyTorch, torchvision (for MNIST), matplotlib, and numpy. We detect whether a GPU is available, and seed every random number generator the notebook touches so that re-running gives exactly the same numbers.
#
# There are five separate sources of randomness in a typical training run: Python's built-in `random`, NumPy's RNG, PyTorch's CPU RNG, PyTorch's CUDA RNG, and cuDNN's choice of which kernel to use. We pin all five below.

# %%
import random
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, random_split
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
import numpy as np

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device: {device}')

# Seed every random number generator we touch, so the notebook is reproducible.
SEED = 0
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)
# Make cuDNN pick deterministic algorithms (slight speed cost; matters only on GPU).
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
# Out:
# Using device: cuda

# %% [markdown]
# ---
#
# ## Problem 1.  A feedforward network on MNIST, step by step

# %% [markdown]
# ### 1.1 Load the MNIST dataset
#
# MNIST is a collection of 70,000 hand-written digit images (60,000 train, 10,000 test), each $28 \times 28$ grayscale, with labels in $\{0, 1, \ldots, 9\}$. Our network takes a flat vector of length $784$, so we need to flatten each image and normalise pixel values to $[0, 1]$. PyTorch handles both through a *transform pipeline* that runs automatically every time a sample is loaded.

# %% [markdown]
# **Step 1: the transform pipeline.** A torchvision transform is a callable that maps one sample to another. We chain several together with `transforms.Compose([...])`, which applies each transform left-to-right (function composition: the output of one is the input of the next). For MNIST we need two steps.
#
# * `transforms.ToTensor()` converts a PIL image (8-bit integers $0, 1, \ldots, 255$) to a float tensor in $[0, 1]$ with shape `(1, 28, 28)`. The division by $255$ happens automatically; this is the normalisation step.
# * `transforms.Lambda(lambda x: x.view(-1))` reshapes that `(1, 28, 28)` tensor into a length-784 vector. This is the flatten step needed because our model is a feedforward (not convolutional) network.
#
# The composed `transform` is attached to the dataset object; each sample passes through it on the fly when loaded.

# %%
transform = transforms.Compose([
    transforms.ToTensor(),                    # PIL image -> float tensor in [0, 1], shape (1, 28, 28)
    transforms.Lambda(lambda x: x.view(-1)),  # flatten to a length-784 vector
])

# %% [markdown]
# **Step 2: load the train and test datasets.** `torchvision.datasets.MNIST` provides the standard dataset. The arguments are:
#
# * `'./data'`: where to store the dataset files on disk. On the first run the files are downloaded; on subsequent runs they are read from cache.
# * `train=True / train=False`: MNIST ships with two fixed partitions, a 60,000-sample training set and a 10,000-sample test set. We load both. The split between them was set by the dataset providers; we do not get to choose it. The convention of separating train from test is universal in supervised learning: anything used during training cannot also be used to evaluate generalisation.
# * `download=True`: download if not present locally (a few megabytes; takes seconds on Colab).
# * `transform=transform`: apply the pipeline above to every sample.

# %%
train_full = datasets.MNIST('./data', train=True,  download=True, transform=transform)
test_set   = datasets.MNIST('./data', train=False, download=True, transform=transform)

print(f'Official train set: {len(train_full):,}    Official test set: {len(test_set):,}')
# Out:
# 100%|██████████| 9.91M/9.91M [00:01<00:00, 5.69MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 135kB/s]
# 100%|██████████| 1.65M/1.65M [00:01<00:00, 1.27MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 10.6MB/s]
# Official train set: 60,000    Official test set: 10,000

# %% [markdown]
# **Step 3: carve a small training set and a validation set out of the official training set.** During training we want to monitor whether the model is generalising, but we are *not* allowed to look at the test set. Any decision we make based on the test set (when to stop, which hyperparameter to pick, which architecture to use) leaks information from it into the model, and the final test accuracy is no longer an honest estimate of generalisation. The standard fix is to carve a *validation* set out of the official training data and keep the test set sealed until the very end.
#
# We use `torch.utils.data.random_split` to partition `train_full` into a 5,000-sample training set, a 10,000-sample validation set, and a 45,000-sample remainder that we discard. The split is deterministic given our seed.
#
# Why only 5,000 training samples when 60,000 are available? **Pedagogical choice.** With the full training set, MNIST is so easy that even a small feedforward network reaches $97\%+$ test accuracy without any regularisation, and we never get to see the regularisers earn their keep. Training on only 5,000 samples makes the network overfit visibly: train accuracy will climb near $100\%$ while test accuracy lags well behind, and that gap is what dropout (and friends) are there to close. In a real project you would use all the data you can get.

# %%
train_set, val_set, _discard = random_split(
    train_full,
    [5_000, 10_000, 45_000],
    generator=torch.Generator().manual_seed(SEED),
)

# %% [markdown]
# **Step 4: batching with `DataLoader`.** A `DataLoader` wraps a dataset and yields mini-batches. We use:
#
# * **Training**: batch size 128, `shuffle=True`. Shuffling each epoch decorrelates the gradient updates across passes and helps generalisation.
# * **Validation and test**: batch size 512, `shuffle=False`. Larger batches are faster (no backprop needed for evaluation) and shuffling has no effect on the result.

# %%
# Explicit generator on the train loader makes the per-epoch shuffle reproducible.
train_loader = DataLoader(train_set, batch_size=128, shuffle=True,
                          generator=torch.Generator().manual_seed(SEED))
val_loader   = DataLoader(val_set,   batch_size=512, shuffle=False)
test_loader  = DataLoader(test_set,  batch_size=512, shuffle=False)

print(f'Train: {len(train_set):,}    Val: {len(val_set):,}    Test: {len(test_set):,}')
# Out:
# Train: 5,000    Val: 10,000    Test: 10,000

# %% [markdown]
# A look at a few training digits with their labels.

# %%
fig, axes = plt.subplots(2, 8, figsize=(10, 3))
for ax, (x, y) in zip(axes.flat, train_set):
    ax.imshow(x.view(28, 28), cmap='gray')
    ax.set_title(f'{y}', fontsize=10)
    ax.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 1.2 Define the model
#
# Our architecture: a feedforward network with two hidden layers,
# $$ 784 \;\xrightarrow{\;W^{[1]}, b^{[1]}\;}\; 128 \;\xrightarrow{\mathrm{ReLU}}\; 128 \;\xrightarrow{\;W^{[2]}, b^{[2]}\;}\; 64 \;\xrightarrow{\mathrm{ReLU}}\; 64 \;\xrightarrow{\;W^{[3]}, b^{[3]}\;}\; 10. $$
# This is exactly the kind of network from Week 2, written in PyTorch building blocks. Each block is a Python object:
#
# * `nn.Linear(in_features, out_features)` is the affine map $x \mapsto Wx + b$. PyTorch creates the weight matrix $W$ (shape `(out_features, in_features)`) and bias vector $b$ as *trainable parameters* automatically; you do not initialise them by hand. The PyTorch default initialisation is close to the Xavier scheme from Week 2 §6.
# * `nn.ReLU()` applies $\max(0, \cdot)$ elementwise. It has no parameters; it is just a function masquerading as a module.
# * `nn.Sequential(layer_1, layer_2, \ldots)` is a container that chains its arguments. Calling `model(x)` runs $x$ through them left-to-right; calling `model.parameters()` returns all trainable parameters across the chain. This is what lets the optimiser update *every* weight matrix in one call.
#
# One subtlety: the final layer outputs raw scores (called *logits*), not probabilities. We do not append a softmax. The reason is numerical: `nn.CrossEntropyLoss` (Section 1.3) applies log-softmax internally with a numerically stable formula, and applying softmax twice would be wasteful and unstable.
#
# After defining the model we call `.to(device)`, which moves all parameter tensors to the GPU if one is available, or leaves them on CPU otherwise. Subsequent inputs `x` also need to be moved to the same device.

# %%
def make_model(hidden1=128, hidden2=64, dropout_p=0.0):
    layers = [
        nn.Linear(784, hidden1),
        nn.ReLU(),
    ]
    if dropout_p > 0:
        layers.append(nn.Dropout(dropout_p))
    layers += [
        nn.Linear(hidden1, hidden2),
        nn.ReLU(),
    ]
    if dropout_p > 0:
        layers.append(nn.Dropout(dropout_p))
    layers += [nn.Linear(hidden2, 10)]
    return nn.Sequential(*layers)

model = make_model().to(device)
n_params = sum(p.numel() for p in model.parameters())
print(model)
print(f'Trainable parameters: {n_params:,}')
# Out:
# Sequential(
#   (0): Linear(in_features=784, out_features=128, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=128, out_features=64, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=64, out_features=10, bias=True)
# )
# Trainable parameters: 109,386

# %% [markdown]
# ### 1.3 Loss function and optimiser
#
# Two PyTorch objects do the heavy lifting during training.
#
# **`nn.CrossEntropyLoss`** is the softmax cross-entropy loss from Week 1. For a single sample with true class $y \in \{0, \ldots, 9\}$ and predicted logits $z \in \mathbb{R}^{10}$, it computes
# $$ \ell(z, y) \;=\; -\log \frac{e^{z_y}}{\sum_{k=0}^{9} e^{z_k}} \;=\; -z_y + \log \sum_k e^{z_k}, $$
# the negative log-probability that the network assigns to the correct class. It accepts logits (not probabilities) precisely so that the log-sum-exp on the right can be evaluated with the numerically stable trick (subtracting $\max_k z_k$ inside the exponentials).
#
# **`optim.SGD`** implements gradient descent. We pass it `model.parameters()` (every weight matrix and bias vector that needs updating) together with two knobs:
#
# * `lr=0.01` is the learning rate $\alpha$ from Week 3 §1, the step size in $\theta \leftarrow \theta - \alpha\, \nabla C(\theta)$.
# * `momentum=0.9` is a mild improvement on plain GD that we will study properly in Week 4. For now, think of it as smoothing the gradient direction across iterations.
#
# After this cell, the optimiser holds *references* to the model's parameters. Calling `optimizer.step()` updates them in place using whatever gradients are currently sitting on them.

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)

# %% [markdown]
# ### 1.4 Training and evaluation loops
#
# Training a network in PyTorch is the same five-line dance, repeated for every mini-batch:
#
# 1. `optimizer.zero_grad()` — set the gradient of every parameter to zero. By default PyTorch *accumulates* gradients into the `.grad` attribute of each parameter, so if you forget this step, you are effectively summing gradients across batches.
# 2. `logits = model(x)` — forward pass. This runs the input through every layer in `nn.Sequential`.
# 3. `loss = criterion(logits, y)` — evaluate the loss as a scalar tensor.
# 4. `loss.backward()` — backpropagation, computed automatically by PyTorch's autograd. We will not implement this by hand in this course, but conceptually it walks the computational graph backwards and fills in $\partial \text{loss} / \partial \theta$ for every learnable parameter $\theta$ (see Week 3, §3-4 for the underlying algorithm).
# 5. `optimizer.step()` — take one gradient descent step using those gradients.
#
# Two more details show up in the helpers below.
#
# * `model.train()` and `model.eval()` switch the model between training mode and evaluation mode. The behaviour of some layers (notably `nn.Dropout` and `nn.BatchNorm`) differs between the two: dropout zeros activations only in train mode; batch norm uses batch statistics in train mode and a running average in eval mode.
# * The `@torch.no_grad()` decorator on `evaluate` tells PyTorch not to build a computational graph for the forward pass, which saves memory and time. Use it whenever you only want predictions, not gradients.
#
# Both functions return the per-sample loss (so values from different batch sizes are comparable) and the classification accuracy.

# %%
def train_one_epoch(model, loader, optimizer, criterion):
    model.train()
    total_loss, total_correct, total_count = 0.0, 0, 0
    for x, y in loader:
        x, y = x.to(device), y.to(device)
        optimizer.zero_grad()
        logits = model(x)
        loss = criterion(logits, y)
        loss.backward()
        optimizer.step()
        total_loss    += loss.item() * x.size(0)
        total_correct += (logits.argmax(dim=1) == y).sum().item()
        total_count   += x.size(0)
    return total_loss / total_count, total_correct / total_count

@torch.no_grad()
def evaluate(model, loader, criterion):
    model.eval()
    total_loss, total_correct, total_count = 0.0, 0, 0
    for x, y in loader:
        x, y = x.to(device), y.to(device)
        logits = model(x)
        loss = criterion(logits, y)
        total_loss    += loss.item() * x.size(0)
        total_correct += (logits.argmax(dim=1) == y).sum().item()
        total_count   += x.size(0)
    return total_loss / total_count, total_correct / total_count

# %% [markdown]
# ### 1.5 Train the model
#
# We wrap everything in a `fit` function that loops over epochs. An *epoch* is one full pass through the training set: with 5,000 samples and batch size 128, the train loader yields $\lceil 5{,}000 / 128 \rceil = 40$ batches per epoch, and we run `train_one_epoch` on all of them. After each epoch we also evaluate on the validation set, so we can watch how the network is doing on data it has not seen during the gradient updates.
#
# We train for 60 epochs. With only 5,000 training samples, an unregularised feedforward network has enough capacity to essentially memorise the training set, and the training accuracy approaches $100\%$. The validation loss, however, plateaus partway through and then starts to creep upward; that movement, validation loss going up while training loss keeps going down, is the textbook signature of overfitting.

# %%
def fit(model, n_epochs=60, lr=0.01, momentum=0.9,
        train_loader=train_loader, val_loader=val_loader):
    optimizer = optim.SGD(model.parameters(), lr=lr, momentum=momentum)
    history = {'train_loss': [], 'val_loss': [], 'train_acc': [], 'val_acc': []}
    for epoch in range(1, n_epochs + 1):
        tr_loss, tr_acc = train_one_epoch(model, train_loader, optimizer, criterion)
        va_loss, va_acc = evaluate(model, val_loader, criterion)
        history['train_loss'].append(tr_loss); history['val_loss'].append(va_loss)
        history['train_acc'].append(tr_acc);   history['val_acc'].append(va_acc)
        print(f'epoch {epoch:2d}  train loss {tr_loss:.4f}  val loss {va_loss:.4f}  '
              f'train acc {tr_acc:.4f}  val acc {va_acc:.4f}')
    return history

torch.manual_seed(SEED)
model_baseline = make_model().to(device)
hist_baseline = fit(model_baseline, n_epochs=60)
# Out:
# epoch  1  train loss 2.2684  val loss 2.1986  train acc 0.1902  val acc 0.4517
# epoch  2  train loss 2.0151  val loss 1.6790  train acc 0.4640  val acc 0.5696
# epoch  3  train loss 1.2619  val loss 0.8814  train acc 0.6866  val acc 0.7578
# epoch  4  train loss 0.7105  val loss 0.6106  train acc 0.7992  val acc 0.8267
# epoch  5  train loss 0.5396  val loss 0.5125  train acc 0.8446  val acc 0.8528
# epoch  6  train loss 0.4543  val loss 0.4535  train acc 0.8740  val acc 0.8702
# epoch  7  train loss 0.3988  val loss 0.4125  train acc 0.8854  val acc 0.8838
# epoch  8  train loss 0.3567  val loss 0.4087  train acc 0.9006  val acc 0.8816
# epoch  9  train loss 0.3344  val loss 0.3772  train acc 0.9058  val acc 0.8918
# epoch 10  train loss 0.3178  val loss 0.3728  train acc 0.9120  val acc 0.8923
# epoch 11  train loss 0.3027  val loss 0.3538  train acc 0.9156  val acc 0.8974
# epoch 12  train loss 0.2813  val loss 0.3453  train acc 0.9198  val acc 0.9021
# epoch 13  train loss 0.2659  val loss 0.3716  train acc 0.9262  val acc 0.8913
# epoch 50  train loss 0.0439  val loss 0.2721  train acc 0.9918  val acc 0.9294
# epoch 51  train loss 0.0398  val loss 0.2711  train acc 0.9948  val acc 0.9305
# epoch 52  train loss 0.0399  val loss 0.2706  train acc 0.9940  val acc 0.9311
# epoch 53  train loss 0.0413  val loss 0.2785  train acc 0.9920  val acc 0.9286
# epoch 54  train loss 0.0367  val loss 0.2822  train acc 0.9940  val acc 0.9274
# epoch 55  train loss 0.0343  val loss 0.2837  train acc 0.9946  val acc 0.9281
# epoch 56  train loss 0.0324  val loss 0.2812  train acc 0.9956  val acc 0.9285
# epoch 57  train loss 0.0294  val loss 0.2769  train acc 0.9964  val acc 0.9307
# epoch 58  train loss 0.0277  val loss 0.2824  train acc 0.9972  val acc 0.9305
# epoch 59  train loss 0.0262  val loss 0.2815  train acc 0.9970  val acc 0.9309
# epoch 60  train loss 0.0239  val loss 0.2807  train acc 0.9980  val acc 0.9317

# %% [markdown]
# ### 1.6 Plot the training curves

# %%
def plot_history(histories, names, title=''):
    fig, (ax_loss, ax_acc) = plt.subplots(1, 2, figsize=(11, 4))
    for h, name in zip(histories, names):
        epochs = range(1, len(h['train_loss']) + 1)
        ax_loss.plot(epochs, h['train_loss'], label=f'{name} train', linestyle='--')
        ax_loss.plot(epochs, h['val_loss'],   label=f'{name} val')
        ax_acc.plot(epochs, h['train_acc'],   label=f'{name} train', linestyle='--')
        ax_acc.plot(epochs, h['val_acc'],     label=f'{name} val')
    ax_loss.set_xlabel('epoch'); ax_loss.set_ylabel('loss'); ax_loss.legend(fontsize=8)
    ax_acc.set_xlabel('epoch'); ax_acc.set_ylabel('accuracy'); ax_acc.legend(fontsize=8)
    if title:
        fig.suptitle(title); fig.tight_layout()
    plt.show()

plot_history([hist_baseline], ['baseline'], title='Baseline FFN on MNIST')

# %% [markdown]
# ### 1.7 Final test accuracy
#
# Now, and only now, we touch the test set. It was sealed during training (we never used it to choose anything: not the architecture, not the learning rate, not the number of epochs). Its accuracy is our honest estimate of how well the model would do on completely new digits.
#
# We will also print the train accuracy at the last epoch and the *generalisation gap* (train minus test). A large positive gap means the model has fit the training data better than the test data, that is, it has memorised some patterns specific to the training set that do not transfer.

# %%
test_loss_baseline, test_acc_baseline = evaluate(model_baseline, test_loader, criterion)
print(f'Baseline test accuracy: {test_acc_baseline:.4f}  (test loss {test_loss_baseline:.4f})')
print(f'Train accuracy at last epoch: {hist_baseline["train_acc"][-1]:.4f}')
print(f'Generalisation gap (train acc minus test acc): '
      f'{hist_baseline["train_acc"][-1] - test_acc_baseline:+.4f}')
# Out:
# Baseline test accuracy: 0.9325  (test loss 0.2581)
# Train accuracy at last epoch: 0.9980
# Generalisation gap (train acc minus test acc): +0.0655

# %% [markdown]
# The gap between train and test accuracy is the network *over-fitting* the training data. Problem 2 attacks it from the dropout side. First, three small experiments.

# %% [markdown]
# > ### <font color="#1b5e20">1.8 Tasks</font>
# >
# > Two small experiments. Run them, look at the numbers, then think about what you observed.
# >
# > <font color="#1b5e20">**Task 1.8.1: change the seed.**</font> Pick another value for `SEED` (try 1, 42, 123) and re-run sections 1.5 through 1.7. How much does the final test accuracy move from run to run? If the seed-to-seed spread is comparable to the dropout-vs-baseline gap, you cannot conclude that dropout helps from a single comparison; you would need to average over seeds.
# >
# > <font color="#1b5e20">**Task 1.8.2: train on Fashion-MNIST.**</font> Fashion-MNIST is a drop-in replacement for MNIST with the same $28 \times 28$ grayscale shape and the same 10 classes, but the labels are clothing items (t-shirt, trouser, pullover, dress, coat, sandal, shirt, sneaker, bag, ankle boot) instead of digits. It is significantly harder than MNIST: the same architecture and recipe typically lands around 80% test accuracy instead of 93%+. In the code cell below, load Fashion-MNIST using `datasets.FashionMNIST` (same constructor signature as `datasets.MNIST`), build a 5,000 / 10,000 train/val split and corresponding DataLoaders, then re-train the baseline model and report the test accuracy alongside the MNIST baseline number. The point is to see that the same pipeline behaves very differently when the data is harder.

# %%
# Task 1.8.2: train the baseline model on Fashion-MNIST.

# 1. Same transform, drop-in dataset class.
fmnist_full     = datasets.FashionMNIST('./data', train=True,  download=True, transform=transform)
fmnist_test_set = datasets.FashionMNIST('./data', train=False, download=True, transform=transform)

# 2. Same 5k / 10k split structure as for MNIST.
fmnist_train_set, fmnist_val_set, _ = random_split(
    fmnist_full,
    [5_000, 10_000, 45_000],
    generator=torch.Generator().manual_seed(SEED),
)

# 3. Same loader configuration; just different underlying datasets.
fmnist_train_loader = DataLoader(fmnist_train_set, batch_size=128, shuffle=True,
                                 generator=torch.Generator().manual_seed(SEED))
fmnist_val_loader   = DataLoader(fmnist_val_set,   batch_size=512, shuffle=False)
fmnist_test_loader  = DataLoader(fmnist_test_set,  batch_size=512, shuffle=False)

# 4-5. Fresh baseline, trained on Fashion-MNIST via fit(..., train_loader=..., val_loader=...).
torch.manual_seed(SEED)
model_fmnist = make_model().to(device)
hist_fmnist  = fit(model_fmnist, n_epochs=60,
                   train_loader=fmnist_train_loader,
                   val_loader=fmnist_val_loader)

# 6. Final test accuracy on Fashion-MNIST vs the MNIST baseline.
_, test_acc_fmnist = evaluate(model_fmnist, fmnist_test_loader, criterion)
print()
print(f'Fashion-MNIST baseline test acc: {test_acc_fmnist:.4f}')
print(f'(MNIST baseline test acc:        {test_acc_baseline:.4f})')
# Out:
# 100%|██████████| 26.4M/26.4M [00:02<00:00, 10.6MB/s]
# 100%|██████████| 29.5k/29.5k [00:00<00:00, 163kB/s]
# 100%|██████████| 4.42M/4.42M [00:01<00:00, 3.08MB/s]
# 100%|██████████| 5.15k/5.15k [00:00<00:00, 26.9MB/s]
# epoch  1  train loss 2.1807  val loss 1.8771  train acc 0.2654  val acc 0.3384
# epoch  2  train loss 1.4261  val loss 1.1033  train acc 0.5272  val acc 0.5733
# epoch  3  train loss 0.9719  val loss 0.8685  train acc 0.6282  val acc 0.6702
# epoch  4  train loss 0.8027  val loss 0.8283  train acc 0.6926  val acc 0.6805
# epoch  5  train loss 0.7438  val loss 0.7190  train acc 0.7202  val acc 0.7501
# epoch  6  train loss 0.6808  val loss 0.6803  train acc 0.7490  val acc 0.7655
# epoch  7  train loss 0.6739  val loss 0.7010  train acc 0.7566  val acc 0.7474
# epoch  8  train loss 0.6145  val loss 0.7416  train acc 0.7838  val acc 0.7210
# epoch  9  train loss 0.6254  val loss 0.6074  train acc 0.7782  val acc 0.7800
# epoch 10  train loss 0.5500  val loss 0.6385  train acc 0.8046  val acc 0.7749
# epoch 11  train loss 0.5680  val loss 0.5871  train acc 0.7988  val acc 0.7889
# epoch 48  train loss 0.2819  val loss 0.6066  train acc 0.9010  val acc 0.7825
# epoch 49  train loss 0.2772  val loss 0.4888  train acc 0.8960  val acc 0.8325
# epoch 50  train loss 0.2463  val loss 0.4800  train acc 0.9160  val acc 0.8346
# epoch 51  train loss 0.2545  val loss 0.4786  train acc 0.9078  val acc 0.8335
# epoch 52  train loss 0.2656  val loss 0.5461  train acc 0.9002  val acc 0.8210
# epoch 53  train loss 0.2698  val loss 0.4886  train acc 0.9056  val acc 0.8334
# epoch 54  train loss 0.2442  val loss 0.5430  train acc 0.9132  val acc 0.8149
# epoch 55  train loss 0.2630  val loss 0.4904  train acc 0.9082  val acc 0.8326
# epoch 56  train loss 0.2287  val loss 0.5146  train acc 0.9162  val acc 0.8236
# epoch 57  train loss 0.2636  val loss 0.4885  train acc 0.9078  val acc 0.8373
# epoch 58  train loss 0.2164  val loss 0.5062  train acc 0.9266  val acc 0.8285
# epoch 59  train loss 0.2202  val loss 0.5429  train acc 0.9230  val acc 0.8278
# epoch 60  train loss 0.2300  val loss 0.5324  train acc 0.9190  val acc 0.8263
#
# Fashion-MNIST baseline test acc: 0.8239
# (MNIST baseline test acc:        0.9325)

# %% [markdown]
# ---
#
# ## Problem 2.  Dropout as an ensemble of thinned networks
#
# Recall (Week 2, §6) that dropout with keep-probability $p$ randomly zeros each hidden unit's activation, independently, each forward pass. The standard story is:
#
# > *Training one network of width $W$ with dropout is approximately equivalent to training an ensemble of $2^W$ thinned subnetworks (each picking a random subset of units) that share parameters; at test time, dropout's prediction is approximately the average of all thinned subnetworks' predictions.*
#
# We cannot afford to enumerate $2^W$ subnetworks. But we can sample $K$ of them, train each one separately on the same data, average their softmax outputs at test time, and compare to a single dropout-trained network. The claim is that the two should land in the same ballpark.
#
# We will compare three things:
#
# 1. **Baseline** (no regularisation) from Problem 1.
# 2. **One dropout net**: one network of width 128 trained with $\mathrm{Dropout}(0.5)$.
# 3. **Ensemble of $K$ thinned nets**: $K$ independent networks of half the width (64 hidden units each), no dropout, trained on the same data. At test time, we average their softmax probabilities.

# %% [markdown]
# ### 2.1 Train one network with dropout
#
# **What `nn.Dropout(p)` actually does.** During *training*, every time a tensor passes through this layer, each entry is independently set to zero with probability $p$ (the *drop* probability) and kept with probability $1-p$. The surviving entries are multiplied by $1/(1-p)$ so that the expected sum of activations is unchanged: this is the *inverted dropout* trick from Week 2 §6. During *evaluation* (`model.eval()`), dropout is the identity, no zeros, no scaling. This is why `model.train()` and `model.eval()` matter.
#
# We add a dropout layer after each ReLU, with keep-probability $1-p = 0.5$.

# %%
torch.manual_seed(SEED)
model_dropout = make_model(hidden1=128, hidden2=64, dropout_p=0.5).to(device)
hist_dropout  = fit(model_dropout, n_epochs=60)
test_loss_dropout, test_acc_dropout = evaluate(model_dropout, test_loader, criterion)
print(f'Dropout test accuracy: {test_acc_dropout:.4f}')
# Out:
# epoch  1  train loss 2.2774  val loss 2.2178  train acc 0.1524  val acc 0.4247
# epoch  2  train loss 2.1194  val loss 1.8691  train acc 0.3268  val acc 0.4738
# epoch 39  train loss 0.2623  val loss 0.2528  train acc 0.9250  val acc 0.9264
# epoch 40  train loss 0.2553  val loss 0.2474  train acc 0.9240  val acc 0.9296
# epoch 41  train loss 0.2590  val loss 0.2454  train acc 0.9212  val acc 0.9273
# epoch 42  train loss 0.2282  val loss 0.2450  train acc 0.9336  val acc 0.9276
# epoch 43  train loss 0.2326  val loss 0.2439  train acc 0.9340  val acc 0.9285
# epoch 44  train loss 0.2354  val loss 0.2474  train acc 0.9286  val acc 0.9268
# epoch 45  train loss 0.2307  val loss 0.2388  train acc 0.9296  val acc 0.9311
# epoch 46  train loss 0.2262  val loss 0.2481  train acc 0.9324  val acc 0.9293
# epoch 47  train loss 0.2160  val loss 0.2416  train acc 0.9374  val acc 0.9307
# epoch 48  train loss 0.2252  val loss 0.2393  train acc 0.9294  val acc 0.9326
# epoch 49  train loss 0.2107  val loss 0.2386  train acc 0.9384  val acc 0.9309
# epoch 50  train loss 0.2045  val loss 0.2350  train acc 0.9386  val acc 0.9320
# epoch 51  train loss 0.2112  val loss 0.2404  train acc 0.9354  val acc 0.9321
# epoch 52  train loss 0.2380  val loss 0.2436  train acc 0.9226  val acc 0.9288
# epoch 53  train loss 0.2035  val loss 0.2440  train acc 0.9370  val acc 0.9312
# epoch 54  train loss 0.2241  val loss 0.2341  train acc 0.9326  val acc 0.9336
# epoch 55  train loss 0.1832  val loss 0.2442  train acc 0.9452  val acc 0.9311
# epoch 56  train loss 0.1743  val loss 0.2419  train acc 0.9482  val acc 0.9327
# epoch 57  train loss 0.1829  val loss 0.2365  train acc 0.9440  val acc 0.9344
# epoch 58  train loss 0.1895  val loss 0.2335  train acc 0.9424  val acc 0.9343
# epoch 59  train loss 0.1822  val loss 0.2363  train acc 0.9470  val acc 0.9342
# epoch 60  train loss 0.1786  val loss 0.2383  train acc 0.9484  val acc 0.9340
# Dropout test accuracy: 0.9371

# %% [markdown]
# ### 2.2 Train $K$ thinned subnetworks
#
# Each thinned network has half the hidden width of the dropout net (a rough match: dropout with $p=0.5$ keeps half the units in expectation). We train $K = 5$ of them, each with a different random initialisation. There is no dropout in the thinned nets.

# %%
K = 5
thinned_models = []
for k in range(K):
    torch.manual_seed(SEED + 1 + k)  # different init each
    m = make_model(hidden1=64, hidden2=32, dropout_p=0.0).to(device)
    print(f'--- Thinned net {k + 1} of {K} ---')
    fit(m, n_epochs=60)
    thinned_models.append(m)

print(f'Trained {len(thinned_models)} thinned subnetworks.')
# Out:
# --- Thinned net 1 of 5 ---
# epoch  1  train loss 2.2911  val loss 2.2522  train acc 0.1048  val acc 0.1863
# epoch  2  train loss 2.1501  val loss 1.9323  train acc 0.3776  val acc 0.5571
# epoch  3  train loss 1.5478  val loss 1.0978  train acc 0.6292  val acc 0.7114
# epoch  4  train loss 0.8679  val loss 0.7013  train acc 0.7620  val acc 0.7874
# epoch  5  train loss 0.6192  val loss 0.5844  train acc 0.8142  val acc 0.8128
# epoch  6  train loss 0.5083  val loss 0.5171  train acc 0.8528  val acc 0.8435
# epoch  7  train loss 0.4413  val loss 0.4541  train acc 0.8746  val acc 0.8701
# epoch  8  train loss 0.3992  val loss 0.4171  train acc 0.8866  val acc 0.8801
# epoch  9  train loss 0.3600  val loss 0.4031  train acc 0.8994  val acc 0.8847
# epoch 10  train loss 0.3400  val loss 0.3794  train acc 0.9058  val acc 0.8905
# epoch 11  train loss 0.3186  val loss 0.3859  train acc 0.9136  val acc 0.8877
# epoch 12  train loss 0.3135  val loss 0.3810  train acc 0.9124  val acc 0.8839
# epoch 13  train loss 0.2951  val loss 0.3666  train acc 0.9154  val acc 0.8922
# epoch 14  train loss 0.2815  val loss 0.3575  train acc 0.9230  val acc 0.8966
# epoch 15  train loss 0.2664  val loss 0.3520  train acc 0.9260  val acc 0.8973
# epoch 16  train loss 0.2569  val loss 0.3392  train acc 0.9270  val acc 0.9028
# epoch 17  train loss 0.2466  val loss 0.3589  train acc 0.9344  val acc 0.8936
# epoch 18  train loss 0.2654  val loss 0.3406  train acc 0.9198  val acc 0.8997
# epoch 19  train loss 0.2304  val loss 0.3380  train acc 0.9342  val acc 0.9041
# epoch 20  train loss 0.2232  val loss 0.3191  train acc 0.9364  val acc 0.9086
# epoch 21  train loss 0.2007  val loss 0.3072  train acc 0.9434  val acc 0.9113
# epoch 22  train loss 0.1906  val loss 0.3102  train acc 0.9450  val acc 0.9092
# epoch 23  train loss 0.1936  val loss 0.3140  train acc 0.9444  val acc 0.9083
# epoch 24  train loss 0.1820  val loss 0.2995  train acc 0.9478  val acc 0.9148
# epoch 25  train loss 0.1785  val loss 0.2948  train acc 0.9478  val acc 0.9139
# epoch 26  train loss 0.1613  val loss 0.3026  train acc 0.9558  val acc 0.9127
# epoch 27  train loss 0.1597  val loss 0.3206  train acc 0.9542  val acc 0.9063
# epoch 28  train loss 0.1709  val loss 0.2976  train acc 0.9470  val acc 0.9132
# epoch 29  train loss 0.1519  val loss 0.3030  train acc 0.9574  val acc 0.9112
# epoch 30  train loss 0.1420  val loss 0.2925  train acc 0.9624  val acc 0.9151
# epoch 31  train loss 0.1360  val loss 0.3071  train acc 0.9628  val acc 0.9122
# epoch 32  train loss 0.1372  val loss 0.2875  train acc 0.9606  val acc 0.9197
# epoch 33  train loss 0.1263  val loss 0.2881  train acc 0.9656  val acc 0.9179
# epoch 34  train loss 0.1133  val loss 0.2912  train acc 0.9698  val acc 0.9181
# epoch 35  train loss 0.1085  val loss 0.3230  train acc 0.9712  val acc 0.9088
# epoch 36  train loss 0.1545  val loss 0.2838  train acc 0.9536  val acc 0.9192
# epoch 37  train loss 0.1044  val loss 0.2856  train acc 0.9732  val acc 0.9205
# epoch 38  train loss 0.0981  val loss 0.2876  train acc 0.9744  val acc 0.9198
# epoch 39  train loss 0.0942  val loss 0.2861  train acc 0.9766  val acc 0.9214
# epoch 40  train loss 0.0868  val loss 0.2842  train acc 0.9808  val acc 0.9225
# epoch 41  train loss 0.0814  val loss 0.2862  train acc 0.9796  val acc 0.9225
# epoch 42  train loss 0.0846  val loss 0.2874  train acc 0.9788  val acc 0.9215
# epoch 43  train loss 0.0764  val loss 0.2931  train acc 0.9822  val acc 0.9200
# epoch 44  train loss 0.0716  val loss 0.2886  train acc 0.9826  val acc 0.9214
# epoch 45  train loss 0.0674  val loss 0.2884  train acc 0.9854  val acc 0.9213
# epoch 46  train loss 0.0784  val loss 0.2812  train acc 0.9802  val acc 0.9235
# epoch 47  train loss 0.0628  val loss 0.2866  train acc 0.9862  val acc 0.9229
# epoch 48  train loss 0.0572  val loss 0.2951  train acc 0.9896  val acc 0.9221
# epoch 49  train loss 0.0540  val loss 0.2849  train acc 0.9900  val acc 0.9241
# epoch 50  train loss 0.0536  val loss 0.2922  train acc 0.9884  val acc 0.9231
# epoch 51  train loss 0.0491  val loss 0.2968  train acc 0.9910  val acc 0.9223
# epoch 52  train loss 0.0619  val loss 0.2968  train acc 0.9862  val acc 0.9212
# epoch 53  train loss 0.0555  val loss 0.2946  train acc 0.9878  val acc 0.9237
# epoch 54  train loss 0.0434  val loss 0.2990  train acc 0.9936  val acc 0.9230
# epoch 55  train loss 0.0399  val loss 0.2941  train acc 0.9938  val acc 0.9247
# epoch 56  train loss 0.0383  val loss 0.2994  train acc 0.9950  val acc 0.9224
# epoch 57  train loss 0.0359  val loss 0.2937  train acc 0.9960  val acc 0.9248
# epoch 58  train loss 0.0331  val loss 0.3019  train acc 0.9960  val acc 0.9233
# epoch 59  train loss 0.0314  val loss 0.2993  train acc 0.9966  val acc 0.9245
# epoch 60  train loss 0.0294  val loss 0.3011  train acc 0.9976  val acc 0.9242
# --- Thinned net 2 of 5 ---
# epoch  1  train loss 2.2687  val loss 2.1903  train acc 0.1572  val acc 0.3312
# epoch  2  train loss 1.9657  val loss 1.5477  train acc 0.6068  val acc 0.7291
# epoch  3  train loss 1.0721  val loss 0.7823  train acc 0.7562  val acc 0.7707
# epoch  4  train loss 0.6369  val loss 0.5456  train acc 0.8184  val acc 0.8430
# epoch  5  train loss 0.4834  val loss 0.4728  train acc 0.8630  val acc 0.8611
# epoch  6  train loss 0.4227  val loss 0.4314  train acc 0.8796  val acc 0.8722
# epoch  7  train loss 0.3798  val loss 0.4156  train acc 0.8926  val acc 0.8760
# epoch  8  train loss 0.3515  val loss 0.3907  train acc 0.9004  val acc 0.8847
# epoch  9  train loss 0.3263  val loss 0.3701  train acc 0.9078  val acc 0.8913
# epoch 10  train loss 0.3225  val loss 0.3731  train acc 0.9080  val acc 0.8901
# epoch 11  train loss 0.2969  val loss 0.3483  train acc 0.9148  val acc 0.8971
# epoch 12  train loss 0.2805  val loss 0.3525  train acc 0.9198  val acc 0.8957
# epoch 13  train loss 0.2661  val loss 0.3431  train acc 0.9260  val acc 0.8986
# epoch 14  train loss 0.2514  val loss 0.3611  train acc 0.9278  val acc 0.8923
# epoch 15  train loss 0.2467  val loss 0.3285  train acc 0.9282  val acc 0.9053
# epoch 16  train loss 0.2359  val loss 0.3166  train acc 0.9326  val acc 0.9067
# epoch 17  train loss 0.2172  val loss 0.3277  train acc 0.9378  val acc 0.9031
# epoch 18  train loss 0.2176  val loss 0.3135  train acc 0.9380  val acc 0.9064
# epoch 19  train loss 0.2046  val loss 0.3247  train acc 0.9422  val acc 0.9057
# epoch 56  train loss 0.0329  val loss 0.2831  train acc 0.9952  val acc 0.9276
# epoch 57  train loss 0.0298  val loss 0.2980  train acc 0.9962  val acc 0.9212
# epoch 58  train loss 0.0292  val loss 0.2931  train acc 0.9960  val acc 0.9258
# epoch 59  train loss 0.0272  val loss 0.2949  train acc 0.9978  val acc 0.9267
# epoch 60  train loss 0.0252  val loss 0.2968  train acc 0.9972  val acc 0.9249
# --- Thinned net 3 of 5 ---
# epoch  1  train loss 2.2530  val loss 2.1488  train acc 0.2288  val acc 0.3893
# epoch  2  train loss 1.8963  val loss 1.4937  train acc 0.4532  val acc 0.5528
# epoch  3  train loss 1.1240  val loss 0.8477  train acc 0.6946  val acc 0.7560
# epoch  4  train loss 0.6955  val loss 0.6163  train acc 0.8020  val acc 0.8075
# epoch  5  train loss 0.5456  val loss 0.5169  train acc 0.8440  val acc 0.8503
# epoch  6  train loss 0.4635  val loss 0.4755  train acc 0.8672  val acc 0.8581
# epoch  7  train loss 0.4052  val loss 0.4443  train acc 0.8900  val acc 0.8719
# epoch  8  train loss 0.3759  val loss 0.4051  train acc 0.8946  val acc 0.8814
# epoch  9  train loss 0.3420  val loss 0.3909  train acc 0.9066  val acc 0.8847
# epoch 10  train loss 0.3312  val loss 0.3662  train acc 0.9040  val acc 0.8920
# epoch 11  train loss 0.2995  val loss 0.3730  train acc 0.9166  val acc 0.8901
# epoch 12  train loss 0.2884  val loss 0.3553  train acc 0.9168  val acc 0.8980
# epoch 13  train loss 0.2717  val loss 0.3437  train acc 0.9258  val acc 0.9007
# epoch 14  train loss 0.2586  val loss 0.3479  train acc 0.9290  val acc 0.8976
# epoch 15  train loss 0.2503  val loss 0.3402  train acc 0.9262  val acc 0.8996
# epoch 16  train loss 0.2338  val loss 0.3278  train acc 0.9320  val acc 0.9044
# epoch 17  train loss 0.2215  val loss 0.3196  train acc 0.9378  val acc 0.9051
# epoch 18  train loss 0.2114  val loss 0.3108  train acc 0.9406  val acc 0.9121
# epoch 19  train loss 0.2051  val loss 0.3132  train acc 0.9410  val acc 0.9121
# epoch 20  train loss 0.1940  val loss 0.3011  train acc 0.9446  val acc 0.9126
# epoch 21  train loss 0.1874  val loss 0.3007  train acc 0.9486  val acc 0.9139
# epoch 22  train loss 0.1746  val loss 0.3083  train acc 0.9520  val acc 0.9075
# epoch 23  train loss 0.1705  val loss 0.3056  train acc 0.9504  val acc 0.9127
# epoch 24  train loss 0.1574  val loss 0.2930  train acc 0.9572  val acc 0.9179
# epoch 25  train loss 0.1614  val loss 0.2886  train acc 0.9524  val acc 0.9164
# epoch 26  train loss 0.1438  val loss 0.3059  train acc 0.9618  val acc 0.9103
# epoch 27  train loss 0.1611  val loss 0.2952  train acc 0.9522  val acc 0.9149
# epoch 28  train loss 0.1422  val loss 0.2858  train acc 0.9616  val acc 0.9197
# epoch 29  train loss 0.1226  val loss 0.2776  train acc 0.9672  val acc 0.9209
# epoch 30  train loss 0.1230  val loss 0.2795  train acc 0.9658  val acc 0.9222
# epoch 31  train loss 0.1097  val loss 0.2797  train acc 0.9700  val acc 0.9218
# epoch 32  train loss 0.1043  val loss 0.2796  train acc 0.9754  val acc 0.9197
# epoch 33  train loss 0.0989  val loss 0.2857  train acc 0.9762  val acc 0.9209
# epoch 34  train loss 0.0952  val loss 0.3013  train acc 0.9764  val acc 0.9164
# epoch 35  train loss 0.0936  val loss 0.2795  train acc 0.9756  val acc 0.9239
# epoch 36  train loss 0.0840  val loss 0.2772  train acc 0.9800  val acc 0.9228
# epoch 37  train loss 0.0790  val loss 0.2738  train acc 0.9806  val acc 0.9252
# epoch 38  train loss 0.0768  val loss 0.2800  train acc 0.9818  val acc 0.9231
# epoch 39  train loss 0.0722  val loss 0.2726  train acc 0.9824  val acc 0.9258
# epoch 40  train loss 0.0688  val loss 0.2806  train acc 0.9830  val acc 0.9223
# epoch 41  train loss 0.0651  val loss 0.2777  train acc 0.9856  val acc 0.9246
# epoch 42  train loss 0.0611  val loss 0.2841  train acc 0.9874  val acc 0.9225
# epoch 43  train loss 0.0582  val loss 0.2749  train acc 0.9874  val acc 0.9253
# epoch 44  train loss 0.0562  val loss 0.2796  train acc 0.9874  val acc 0.9249
# epoch 45  train loss 0.0519  val loss 0.2778  train acc 0.9896  val acc 0.9276
# epoch 46  train loss 0.0479  val loss 0.2781  train acc 0.9908  val acc 0.9254
# epoch 47  train loss 0.0533  val loss 0.2838  train acc 0.9876  val acc 0.9246
# epoch 48  train loss 0.0460  val loss 0.2799  train acc 0.9910  val acc 0.9264
# epoch 49  train loss 0.0475  val loss 0.2927  train acc 0.9900  val acc 0.9233
# epoch 50  train loss 0.0404  val loss 0.2917  train acc 0.9928  val acc 0.9245
# epoch 51  train loss 0.0429  val loss 0.2897  train acc 0.9928  val acc 0.9250
# epoch 52  train loss 0.0380  val loss 0.2931  train acc 0.9930  val acc 0.9236
# epoch 53  train loss 0.0362  val loss 0.2880  train acc 0.9940  val acc 0.9263
# epoch 54  train loss 0.0420  val loss 0.2929  train acc 0.9924  val acc 0.9239
# epoch 55  train loss 0.0307  val loss 0.2844  train acc 0.9958  val acc 0.9282
# epoch 56  train loss 0.0289  val loss 0.2953  train acc 0.9968  val acc 0.9258
# epoch 57  train loss 0.0273  val loss 0.2920  train acc 0.9966  val acc 0.9262
# epoch 58  train loss 0.0255  val loss 0.2951  train acc 0.9972  val acc 0.9256
# epoch 59  train loss 0.0258  val loss 0.2949  train acc 0.9966  val acc 0.9254
# epoch 60  train loss 0.0286  val loss 0.2961  train acc 0.9950  val acc 0.9269
# --- Thinned net 4 of 5 ---
# epoch  1  train loss 2.2829  val loss 2.2341  train acc 0.1562  val acc 0.2492
# epoch  2  train loss 2.0962  val loss 1.8370  train acc 0.5120  val acc 0.6042
# epoch  3  train loss 1.4192  val loss 0.9853  train acc 0.6672  val acc 0.7331
# epoch  4  train loss 0.7593  val loss 0.6256  train acc 0.7998  val acc 0.8132
# epoch  5  train loss 0.5558  val loss 0.5061  train acc 0.8464  val acc 0.8559
# epoch  6  train loss 0.4570  val loss 0.4573  train acc 0.8724  val acc 0.8662
# epoch  7  train loss 0.4042  val loss 0.4138  train acc 0.8850  val acc 0.8819
# epoch  8  train loss 0.3672  val loss 0.3947  train acc 0.8942  val acc 0.8848
# epoch  9  train loss 0.3444  val loss 0.3744  train acc 0.9020  val acc 0.8917
# epoch 10  train loss 0.3350  val loss 0.3691  train acc 0.9072  val acc 0.8913
# epoch 11  train loss 0.3132  val loss 0.3813  train acc 0.9120  val acc 0.8853
# epoch 12  train loss 0.3066  val loss 0.3564  train acc 0.9122  val acc 0.8983
# epoch 13  train loss 0.2852  val loss 0.3471  train acc 0.9212  val acc 0.9013
# epoch 14  train loss 0.2688  val loss 0.3415  train acc 0.9256  val acc 0.8992
# epoch 15  train loss 0.2564  val loss 0.3602  train acc 0.9258  val acc 0.8933
# epoch 16  train loss 0.2520  val loss 0.3473  train acc 0.9294  val acc 0.8986
# epoch 17  train loss 0.2389  val loss 0.3373  train acc 0.9344  val acc 0.9032
# epoch 18  train loss 0.2255  val loss 0.3299  train acc 0.9376  val acc 0.9033
# epoch 19  train loss 0.2235  val loss 0.3234  train acc 0.9364  val acc 0.9107
# epoch 20  train loss 0.2086  val loss 0.3308  train acc 0.9442  val acc 0.9044
# epoch 21  train loss 0.1959  val loss 0.3094  train acc 0.9460  val acc 0.9123
# epoch 22  train loss 0.1925  val loss 0.3190  train acc 0.9472  val acc 0.9082
# epoch 23  train loss 0.1885  val loss 0.3139  train acc 0.9448  val acc 0.9061
# epoch 24  train loss 0.1824  val loss 0.3022  train acc 0.9500  val acc 0.9154
# epoch 25  train loss 0.1690  val loss 0.3091  train acc 0.9540  val acc 0.9121
# epoch 26  train loss 0.1649  val loss 0.3036  train acc 0.9544  val acc 0.9169
# epoch 27  train loss 0.1544  val loss 0.3033  train acc 0.9610  val acc 0.9164
# epoch 28  train loss 0.1474  val loss 0.3005  train acc 0.9586  val acc 0.9146
# epoch 29  train loss 0.1554  val loss 0.2893  train acc 0.9562  val acc 0.9186
# epoch 30  train loss 0.1358  val loss 0.2926  train acc 0.9660  val acc 0.9179
# epoch 31  train loss 0.1320  val loss 0.3056  train acc 0.9668  val acc 0.9122
# epoch 32  train loss 0.1279  val loss 0.2961  train acc 0.9658  val acc 0.9167
# epoch 33  train loss 0.1233  val loss 0.2930  train acc 0.9662  val acc 0.9171
# epoch 34  train loss 0.1204  val loss 0.2966  train acc 0.9688  val acc 0.9177
# epoch 35  train loss 0.1116  val loss 0.2864  train acc 0.9720  val acc 0.9203
# epoch 36  train loss 0.1072  val loss 0.2879  train acc 0.9724  val acc 0.9217
# epoch 37  train loss 0.1014  val loss 0.2917  train acc 0.9762  val acc 0.9201
# epoch 38  train loss 0.0970  val loss 0.2897  train acc 0.9766  val acc 0.9203
# epoch 39  train loss 0.0925  val loss 0.3002  train acc 0.9794  val acc 0.9170
# epoch 40  train loss 0.0928  val loss 0.2933  train acc 0.9788  val acc 0.9169
# epoch 41  train loss 0.0876  val loss 0.2917  train acc 0.9796  val acc 0.9192
# epoch 42  train loss 0.0790  val loss 0.2916  train acc 0.9824  val acc 0.9199
# epoch 43  train loss 0.0761  val loss 0.2958  train acc 0.9824  val acc 0.9213
# epoch 20  train loss 0.2095  val loss 0.3299  train acc 0.9404  val acc 0.9075
# epoch 21  train loss 0.2006  val loss 0.3254  train acc 0.9404  val acc 0.9055
# epoch 22  train loss 0.1894  val loss 0.3120  train acc 0.9490  val acc 0.9112
# epoch 23  train loss 0.1817  val loss 0.3166  train acc 0.9522  val acc 0.9085
# epoch 24  train loss 0.1720  val loss 0.3393  train acc 0.9516  val acc 0.9003
# epoch 25  train loss 0.1695  val loss 0.2989  train acc 0.9552  val acc 0.9168
# epoch 26  train loss 0.1560  val loss 0.3060  train acc 0.9584  val acc 0.9121
# epoch 27  train loss 0.1534  val loss 0.3052  train acc 0.9594  val acc 0.9140
# epoch 28  train loss 0.1441  val loss 0.2942  train acc 0.9612  val acc 0.9198
# epoch 29  train loss 0.1406  val loss 0.3096  train acc 0.9620  val acc 0.9103
# epoch 30  train loss 0.1385  val loss 0.2967  train acc 0.9618  val acc 0.9167
# epoch 31  train loss 0.1264  val loss 0.3022  train acc 0.9664  val acc 0.9150
# epoch 32  train loss 0.1226  val loss 0.2943  train acc 0.9684  val acc 0.9188
# epoch 33  train loss 0.1222  val loss 0.2990  train acc 0.9676  val acc 0.9164
# epoch 34  train loss 0.1123  val loss 0.3039  train acc 0.9704  val acc 0.9179
# epoch 35  train loss 0.1259  val loss 0.2963  train acc 0.9656  val acc 0.9171
# epoch 36  train loss 0.1052  val loss 0.2974  train acc 0.9730  val acc 0.9178
# epoch 37  train loss 0.0961  val loss 0.2858  train acc 0.9776  val acc 0.9217
# epoch 38  train loss 0.0915  val loss 0.3040  train acc 0.9784  val acc 0.9165
# epoch 39  train loss 0.0891  val loss 0.2841  train acc 0.9786  val acc 0.9235
# epoch 40  train loss 0.0815  val loss 0.2876  train acc 0.9810  val acc 0.9218
# epoch 41  train loss 0.0783  val loss 0.2936  train acc 0.9816  val acc 0.9201
# epoch 42  train loss 0.0726  val loss 0.2910  train acc 0.9836  val acc 0.9224
# epoch 43  train loss 0.0722  val loss 0.2964  train acc 0.9826  val acc 0.9212
# epoch 44  train loss 0.0805  val loss 0.2956  train acc 0.9808  val acc 0.9236
# epoch 45  train loss 0.0799  val loss 0.2910  train acc 0.9792  val acc 0.9230
# epoch 46  train loss 0.0619  val loss 0.2954  train acc 0.9864  val acc 0.9230
# epoch 47  train loss 0.0563  val loss 0.2940  train acc 0.9892  val acc 0.9253
# epoch 48  train loss 0.0528  val loss 0.2944  train acc 0.9898  val acc 0.9228
# epoch 49  train loss 0.0510  val loss 0.2942  train acc 0.9904  val acc 0.9241
# epoch 50  train loss 0.0484  val loss 0.3199  train acc 0.9916  val acc 0.9153
# epoch 51  train loss 0.0864  val loss 0.2985  train acc 0.9748  val acc 0.9241
# epoch 52  train loss 0.0474  val loss 0.2922  train acc 0.9904  val acc 0.9256
# epoch 53  train loss 0.0417  val loss 0.2985  train acc 0.9926  val acc 0.9238
# epoch 54  train loss 0.0372  val loss 0.2925  train acc 0.9944  val acc 0.9266
# epoch 55  train loss 0.0489  val loss 0.3052  train acc 0.9910  val acc 0.9231
# epoch 56  train loss 0.0365  val loss 0.2931  train acc 0.9956  val acc 0.9273
# epoch 57  train loss 0.0338  val loss 0.2958  train acc 0.9946  val acc 0.9269
# epoch 58  train loss 0.0300  val loss 0.2954  train acc 0.9968  val acc 0.9276
# epoch 59  train loss 0.0281  val loss 0.2988  train acc 0.9976  val acc 0.9270
# epoch 60  train loss 0.0272  val loss 0.3017  train acc 0.9976  val acc 0.9275
# Trained 5 thinned subnetworks.

# %% [markdown]
# ### 2.3 Ensemble prediction
#
# At test time, each thinned net returns logits; we apply softmax, average the resulting probability vectors across the $K$ networks, then take the argmax. This is the standard ensemble rule.

# %%
@torch.no_grad()
def ensemble_predict(models, loader):
    """Return overall test accuracy of the softmax-averaged ensemble."""
    for m in models:
        m.eval()
    total_correct, total_count = 0, 0
    for x, y in loader:
        x, y = x.to(device), y.to(device)
        probs = torch.zeros(x.size(0), 10, device=device)
        for m in models:
            probs += torch.softmax(m(x), dim=1)
        probs /= len(models)
        preds = probs.argmax(dim=1)
        total_correct += (preds == y).sum().item()
        total_count   += x.size(0)
    return total_correct / total_count

test_acc_ensemble = ensemble_predict(thinned_models, test_loader)
print(f'Ensemble test accuracy (K = {K} thinned nets): {test_acc_ensemble:.4f}')
# Out:
# Ensemble test accuracy (K = 5 thinned nets): 0.9347

# %% [markdown]
# ### 2.4 Side-by-side comparison
#
# Three test accuracies: the unregularised baseline, the single dropout network, and the ensemble of $K$ thinned subnetworks.

# %%
thinned_individual_accs = []
for k, m in enumerate(thinned_models):
    _, acc = evaluate(m, test_loader, criterion)
    thinned_individual_accs.append(acc)

print('Test accuracies:')
print(f'  baseline (no regularisation):   {test_acc_baseline:.4f}')
print(f'  one net with dropout(0.5):      {test_acc_dropout:.4f}')
print(f'  best individual thinned net:    {max(thinned_individual_accs):.4f}')
print(f'  mean individual thinned net:    {np.mean(thinned_individual_accs):.4f}')
print(f'  ensemble of {K} thinned nets:    {test_acc_ensemble:.4f}')

fig, ax = plt.subplots(figsize=(7, 4))
labels = ['baseline', 'dropout', 'thinned\n(best)', 'thinned\n(mean)', f'ensemble\n(K={K})']
values = [test_acc_baseline, test_acc_dropout, max(thinned_individual_accs),
          float(np.mean(thinned_individual_accs)), test_acc_ensemble]
bars = ax.bar(labels, values, color=['gray', 'C0', 'C2', 'C2', 'C3'])
for b, v in zip(bars, values):
    ax.text(b.get_x() + b.get_width() / 2, v + 0.001, f'{v:.4f}',
            ha='center', va='bottom', fontsize=9)
ax.set_ylim(min(values) - 0.01, max(values) + 0.01)
ax.set_ylabel('test accuracy')
ax.set_title('Dropout vs ensemble of thinned networks')
plt.tight_layout(); plt.show()
# Out:
# Test accuracies:
#   baseline (no regularisation):   0.9325
#   one net with dropout(0.5):      0.9371
#   best individual thinned net:    0.9302
#   mean individual thinned net:    0.9288
#   ensemble of 5 thinned nets:    0.9347

# %% [markdown]
# ### 2.5 What did we just see?
#
# Read off the bar chart. Three things to notice.
#
# * **The baseline overfits.** Its training accuracy reached close to $100\%$ but its test accuracy is significantly lower; this is the gap that regularisation is meant to close.
# * **The single dropout net closes that gap.** Trained on the same 5,000 samples with the same architecture, but with `nn.Dropout(0.5)` between the hidden layers, it generalises better than the baseline. The randomness during training prevents the net from memorising any single training pattern too aggressively.
# * **The ensemble of $K$ thinned subnetworks closes the gap by another route, and ends up at a similar test accuracy to the dropout net.** Each thinned net individually has lower capacity and underfits a bit; averaging $K$ of them cancels the idiosyncratic errors of each one.
#
# That last point is the empirical content of the dropout-as-ensemble claim. Dropout buys you the variance-reduction benefit of ensembling *without* having to train, store, and run $K$ separate networks. One parameter vector implicitly carries the averaged behaviour of an exponentially large family of thinned subnetworks; at test time, a single forward pass through the full network is approximately the ensemble's averaged prediction.

# %% [markdown]
# > ### <font color="#1b5e20">2.6 Tasks</font>
# >
# > Two tasks. The second is the most interesting thing in the notebook; do not skip it.
# >
# > <font color="#1b5e20">**Task 2.6.1: change the dropout rate.**</font> Re-run section 2.1 with $p = 0.2$ and then $p = 0.8$. Plot the validation curves alongside the original $p = 0.5$ result. Does a higher dropout rate always help? Why does $p = 0.8$ hurt? Connect to the Week 2 §6 view that dropout effectively reduces the capacity used per forward pass by a factor of $1 - p$.
# >
# > <font color="#1b5e20">**Task 2.6.2: Monte Carlo dropout at test time.**</font> When we evaluated the dropout net in section 2.1 we called `model.eval()`, which switches `nn.Dropout` into pass-through mode and gives us one deterministic forward pass. Try the *opposite*: put the trained `model_dropout` into train mode (`model_dropout.train()`), then push the test set through it $T = 20$ times, each time with a fresh random dropout mask, and average the $T$ softmax outputs before taking the argmax. (Hint: this is essentially `ensemble_predict` from section 2.3 but with *one* trained network instead of $K$ separate ones; use the `@torch.no_grad()` decorator to skip gradient tracking, but do *not* call `model.eval()`.) You should now have three test accuracies for comparison: the standard dropout-off test pass from section 2.1, the $K$-thinned-net ensemble from section 2.4, and this new Monte Carlo dropout number. All three should land within a fraction of a percent of each other. This is the dropout-as-ensemble equivalence made empirical from a fresh angle: the trained dropout network already carries the ensemble *inside* it, and you can recover the averaged prediction by sampling subnetworks at test time, no separate networks required. (For the curious: this trick is called *Monte Carlo dropout*; Gal and Ghahramani (2016) use it to get cheap predictive uncertainty estimates from deep networks.)

# %%
# Task 2.6.2: Monte Carlo dropout at test time.

# 1. Switch model_dropout into train mode so nn.Dropout keeps sampling
#    Bernoulli masks during the test pass. (no_grad still applies, so we save
#    memory by not building a backward graph.)
model_dropout.train()

@torch.no_grad()
def mc_dropout_predict(model, loader, T):
    correct, count = 0, 0
    for x, y in loader:
        x, y = x.to(device), y.to(device)
        probs = torch.zeros(x.size(0), 10, device=device)
        for _ in range(T):
            probs += torch.softmax(model(x), dim=1)
        probs /= T
        correct += (probs.argmax(dim=1) == y).sum().item()
        count   += x.size(0)
    return correct / count

T = 20
acc_mc = mc_dropout_predict(model_dropout, test_loader, T)

# Three routes to (approximately) the same expected prediction over thinned subnets:
print(f'Standard test pass (dropout OFF, model.eval):  {test_acc_dropout:.4f}')
print(f'K-thinned-net ensemble (K = {K}):               {test_acc_ensemble:.4f}')
print(f'Monte Carlo dropout (T = {T} train-mode passes): {acc_mc:.4f}')
# Out:
# Standard test pass (dropout OFF, model.eval):  0.9371
# K-thinned-net ensemble (K = 5):               0.9347
# Monte Carlo dropout (T = 20 train-mode passes): 0.9340
